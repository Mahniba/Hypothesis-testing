# %%
import numpy as np
import scipy.stats as stats

def one_sample_t_test():
    # User input
    sample_mean = int(input("Enter the sample mean: "))
    population_mean = float(input("Enter the population mean: "))
    sample_std = float(input("Enter the sample standard deviation:"))                        
    sample_size = int(input("Enter the sample size"))
    
    # Calculate the t-statistic
    t_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
    
    # Calculate degrees of freedom
    df = sample_size - 1
    
    # Calculate p-value
    p_value = stats.t.sf(np.abs(t_statistic), df) * 2  # two-tailed p-value
    
    # Output results
    print(f"T-Statistic: {t_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

one_sample_t_test()
# Out:
# Enter the sample mean:  80
# Enter the population mean:  50
# Enter the sample standard deviation: 15
# Enter the sample size 25
# T-Statistic: 10.0000
# P-Value: 0.0000

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

def two_sample_t_test():
    # User input
    mean1 = float(input("Enter the sample mean for sample 1 (X̄1): "))
    std1 = float(input("Enter the sample standard deviation for sample 1 (s1): "))
    n1 = int(input("Enter the sample size for sample 1 (n1): "))
    
    mean2 = float(input("Enter the sample mean for sample 2 (X̄2): "))
    std2 = float(input("Enter the sample standard deviation for sample 2 (s2): "))
    n2 = int(input("Enter the sample size for sample 2 (n2): "))
    
    alpha = float(input("Enter the significance level (e.g., 0.05 for 5%): "))
    
    # Calculate the t-statistic for equal variances
    pooled_std = np.sqrt(((n1 - 1) * std1**2 + (n2 - 1) * std2**2) / (n1 + n2 - 2))
    t_statistic = (mean1 - mean2) / (pooled_std * np.sqrt(1/n1 + 1/n2))
    
    # Calculate degrees of freedom
    df = n1 + n2 - 2
    
    # Calculate critical value
    critical_value = t.ppf(1 - alpha / 2, df)
    
    # Calculate p-value
    p_value = t.sf(np.abs(t_statistic), df) * 2  # two-tailed p-value
    
    # Output results
    print(f"T-Statistic: {t_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")
    print(f"Critical Value: ±{critical_value:.4f}")
    
    # Plotting
    x = np.linspace(-4, 4, 1000)
    y = t.pdf(x, df)
    
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label='T Distribution')
    
    # Shade the critical regions
    plt.fill_between(x, 0, y, where=(x <= -critical_value) | (x >= critical_value), color='red', alpha=0.5, label='Critical Regions')
    plt.axvline(t_statistic, color='blue', linestyle='--', linewidth=2, label=f'T-Statistic = {t_statistic:.2f}')
    plt.axvline(-critical_value, color='red', linestyle='--', linewidth=2)
    plt.axvline(critical_value, color='red', linestyle='--', linewidth=2)
    
    plt.xlabel('T-Statistic')
    plt.ylabel('Probability Density')
    plt.title('Two-Sample T-Test Critical Regions')
    plt.legend()
    plt.grid(True)
    plt.show()
49

two_sample_t_test()
# Out:
# Enter the sample mean for sample 1 (X̄1):  86
# Enter the sample standard deviation for sample 1 (s1):  49
# Enter the sample size for sample 1 (n1):  15
# Enter the sample mean for sample 2 (X̄2):  86
# Enter the sample standard deviation for sample 2 (s2):  64
# Enter the sample size for sample 2 (n2):  10
# Enter the significance level (e.g., 0.05 for 5%):  0.05
# T-Statistic: 0.0000
# P-Value: 1.0000
# Critical Value: ±2.0687

# %%
import numpy as np
import scipy.stats as stats

def two_sample_t_test():
    # User input
    sample1_data = input("Enter the data for sample 1 (comma-separated): ")
    sample2_data = input("Enter the data for sample 2 (comma-separated): ")
    
    # Convert input strings to lists of floats
    sample1_data = list(map(float, sample1_data.split(',')))
    sample2_data = list(map(float, sample2_data.split(',')))
    
    # Calculate means and standard deviations
    mean1 = np.mean(sample1_data)
    mean2 = np.mean(sample2_data)
    std1 = np.std(sample1_data, ddof=1)
    std2 = np.std(sample2_data, ddof=1)
    n1 = len(sample1_data)
    n2 = len(sample2_data)
    
    # Calculate the t-statistic for equal variances
    pooled_std = np.sqrt(((n1 - 1) * std1**2 + (n2 - 1) * std2**2) / (n1 + n2 - 2))
    t_statistic = (mean1 - mean2) / (pooled_std * np.sqrt(1/n1 + 1/n2))
    
    # Calculate degrees of freedom
    df = n1 + n2 - 2
    
    # Calculate p-value
    p_value = stats.t.sf(np.abs(t_statistic), df) * 2  # two-tailed p-value
    
    # Output results
    print(f"T-Statistic: {t_statistic:.4f}")
    print(f"P-Value: {p_value:.4f}")

two_sample_t_test()
